# %% [markdown]
# # Neurodocker
#
# _Neurodocker_ is a Python project that generates custom Dockerfiles for neuroimaging and minifies existing Docker images (using [ReproZip](https://www.reprozip.org/)). The package can be used from the command-line or within a Python script. The command-line interface generates Dockerfiles and minifies Docker images, but interaction with the Docker Engine is left to the various `docker` commands. Within a Python script, however, _Neurodocker_ can generate Dockerfiles, build Docker images, run commands within resulting containers (using the [`docker` Python package](https://github.com/docker/docker-py)), and minify Docker images. The project is used for regression testing of [Nipype](https://github.com/nipy/nipype/) interfaces.
#
# Examples in this notebook:
#   - Command-line
#     - [Generate Dockerfile](#generate-dockerfile)
#     - [Generate Dockerfile (full)](#generate-dockerfile-full)
#   - In a Python script
#     - [Generate Dockerfile, build Docker image, run commands in image (minimal)](#generate-dockerfile-build-docker-image-run-commands-in-image-minimal)
#     - [Generate full Dockerfile](#generate-full-dockerfile)
#       - [Generated Dockerfile](examples/generated-full.Dockerfile)
#   - Minimize Docker image
#     - [Minimize existing Docker image](#minimize-existing-docker-image)
#     - [Example of minimizing Docker image for FreeSurfer recon-all](https://github.com/freesurfer/freesurfer/issues/70#issuecomment-316361886)
#
#
# ## Note to users
#
# This software is still in the early stages of development. If you come across an issue or a way to improve _Neurodocker_, please submit an issue or a pull request.

# %% [markdown]
# # Installation
#
# You can install _Neurodocker_ with `pip`, or you can use the project's Docker image.
#
# `pip install https://github.com/kaczmarj/neurodocker/archive/master.tar.gz`
#
# or
#
# `docker run --rm kaczmarj/neurodocker --help`
#
# Note that building and minifying Docker images is not possible within the _Neurodocker_ Docker image.

# %% [markdown]
# # Supported Software
#
# Valid options for each software package are the keyword arguments for the class that installs that package. These classes live in [`neurodocker.interfaces`](neurodocker/interfaces/). The default installation behavior for every software package (except Miniconda) is to install by downloading and un-compressing the binaries.
#
#
# | software | argument | description |
# | -------- | -------- | ----------- |
# | **AFNI** | version* | Either 17.2.02 or latest. |
# | **ANTs** | version* | 2.2.0, 2.1.0, 2.0.3, or 2.0.0 |
# |          | use_binaries | If true (default), use pre-compiled binaries. If false, build from source. |
# |          | git_hash  | Git hash to checkout to before building from source (only used if use_binaries is false). |
# | **FreeSurfer** | version* | Any version for which binaries are provided. |
# |                | license_path | Relative path to license file. If provided, this file will be copied into the Docker image. Must be within the build context. |
# |                | min | If true, install a version of FreeSurfer minimized for recon-all. See [freesurfer/freesurfer#70](https://github.com/freesurfer/freesurfer/issues/70). False by default. |
# | **FSL**** | version* | Any version for which binaries are provided. |
# |           | use_binaries | If true (default), use pre-compiled binaries. Building from source is not available now but might be added in the future. |
# |           | use_installer | If true, use FSL's Python installer. Only valid on CentOS images. |
# | **Miniconda** | env_name* | Name of this conda environment. |
# |               | python_version* | Version of Python. |
# |               | conda_install | Packages to install with conda. e.g., `conda_install="numpy traits"` |
# |               | pip_install | Packages to install with pip. |
# |               | conda_opts  | Command-line options to pass to [`conda create`](https://conda.io/docs/commands/conda-create.html). e.g., `conda_opts="-c vida-nyu"` |
# |               | pip_opts    | Command-line options to pass to [`pip install`](https://pip.pypa.io/en/stable/reference/pip_install/#options). |
# |               | add_to_path | If true (default), add this environment to $PATH. |
# |               | miniconda_version | Version of Miniconda. Latest by default. |
# | **MRtrix3** | use_binaries | If true (default), use pre-compiled binaries. If false, build from source. |
# |             | git_hash | Git hash to checkout to before building from source (only used if use_binaries is false). |
# | **NeuroDebian** | os_codename* | Codename of the operating system (e.g., stretch, zesty). |
# |                 | download_server* | Server to download NeuroDebian packages from. Choose the one closest to you. See `neurodocker generate --help` for the full list of servers. |
# |                 | pkgs | Packages to download from NeuroDebian. |
# |                 | full | If true (default), use non-free sources. If false, use libre sources. |
# | **SPM** | version        | 12 (earlier versions will be supported in the future). |
# |         | matlab_version | R2017a (other MCR versions will be supported once earlier SPM versions are supported). |
#
#
# \* required argument.
#
# ** FSL is non-free. If you are considering commercial use of FSL, please consult the [relevant license](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/Licence).

# %% [markdown]
# # Examples
#
# ## Generate Dockerfile
#
# Generate Dockerfile, and print result to stdout. The result can be piped to `docker build` to build the Docker image.
#
# ```shell
# docker run --rm kaczmarj/neurodocker generate -b ubuntu:17.04 -p apt --ants version=2.2.0
#
# docker run --rm kaczmarj/neurodocker generate -b ubuntu:17.04 -p apt --ants version=2.2.0 | docker build -
# ```

# %% [markdown]
# ## Generate Dockerfile (full)
#
# In this example, a Dockerfile is generated with all of the software that _Neurodocker_ supports, and the Dockerfile is saved to disk. The order in which the arguments are given is preserved in the Dockerfile. The saved Dockerfile can be passed to `docker build`.
#
# ```shell
# # Generate Dockerfile.
# docker run --rm kaczmarj/neurodocker generate \
# --base debian:stretch --pkg-manager apt \
# --install git vim \
# --afni version=latest \
# --ants version=2.2.0 \
# --freesurfer version=6.0.0 min=true \
# --fsl version=5.0.10 \
# --user=neuro \
# --miniconda env_name=default \
#             python_version=3.5.1 \
#             conda_opts="--channel vida-nyu" \
#             conda_install="numpy pandas reprozip traits" \
#             pip_install="nipype" \
# --miniconda env_name=py27 \
#             python_version=2.7 \
#             add_to_path=false \
# --user=root \
# --mrtrix3 \
# --neurodebian os_codename="jessie" \
#               download_server="usa-nh" \
#               pkgs="dcm2niix git-annex-standalone" \
# --spm version=12 matlab_version=R2017a \
# --user=neuro \
# --env KEY_A=VAL_A KEY_B=VAL_B \
# --env KEY_C="based on \$KEY_A" \
# --instruction='RUN mkdir /opt/mydir' \
# --add-to-entrypoint 'echo hello world' 'source myfile.sh' \
# --expose 8888 \
# --workdir /home/neuro \
# --no-check-urls > examples/generated-full.Dockerfile
#
# # Build Docker image using the saved Dockerfile.
# docker build -t myimage -f generated-full.Dockerfile examples
# ```
#
# Here is the [Dockerfile](examples/generated-full.Dockerfile) generated by the command above.

# %% [markdown]
# ## Exercise 1:
#
# Create a docker image based on `neurodebin:stretch-non-free` and use apt to install `FSL`. Determine the FSL version.
# Then create another image based on the same base image but with FSL `5.0.10`.

# %% [markdown]
# ```bash
# docker run --rm kaczmarj/neurodocker generate \
# --base neurodebian:stretch-non-free --pkg-manager apt \
# --install fsl-complete | docker build -t fsl-unknown -
#
#
# docker run -it --rm fsl-unknown cat /usr/share/fsl/etc/fslversion
# ```

# %% [markdown]
# ```bash
#
# docker run --rm kaczmarj/neurodocker generate \
# --base neurodebian:stretch-non-free --pkg-manager apt \
# --fsl version=5.0.10 | docker build -t fsl5.10 -
# ```

# %% [markdown]
# ## Generate Dockerfile, build Docker image, run commands in image (minimal)
#
# In this example, a dictionary of specifications is used to generate a Dockerfile. A Docker image is built from the string representation of the Dockerfile. A container is started from that container, and commands are run within the running container. When finished, the container is stopped and removed.
#
#
# ```python
# from neurodocker import Dockerfile
# from neurodocker.docker import DockerImage, DockerContainer
#
# specs = {
#     'pkg_manager': 'apt',
#     'check_urls': False,
#     'instructions': [
#         ('base', 'ubuntu:17.04'),
#         ('ants', {'version': '2.2.0'})
#     ]
# }
# # Create Dockerfile.
# df = Dockerfile(specs)
#
# # Build image.
# image = DockerImage(df).build(log_console=False, log_filepath="build.log")
#
# # Start container, and run commands.
# container = DockerContainer(image).start()
# container.exec_run('antsRegistration --help')
# container.exec_run('ls /')
# container.cleanup(remove=True)
# ```

# %% [markdown]
# ## Generate full Dockerfile
#
# In this example, we create a Dockerfile with all of the software that _Neurodocker_ supports, and we supply arbitrary Dockerfile instructions.
#
# ```python
# from neurodocker import Dockerfile
#
# specs = {
#     'pkg_manager': 'apt',
#     'check_urls': False,
#     'instructions': [
#         ('base', 'ubuntu:17.04'),
#         ('install', ['git', 'vim']),
#         ('user', 'neuro'),
#         ('miniconda', {
#             'env_name': 'my_env',
#             'python_version': '3.5.1',
#             'conda_install': 'traits',
#             'pip_install': 'https://github.com/nipy/nipype/archive/master.tar.gz'}),
#         ('user', 'root'),
#         ('afni', {'version': 'latest'}),
#         ('ants', {'version': '2.2.0'}),
#         ('freesurfer', {'version': '6.0.0', 'license_path': 'rel/path/license.txt'}),
#         ('fsl', {'version': '5.0.10', 'use_binaries': True}),
#         ('mrtrix3', {'use_binaries': False}),
#         ('neurodebian', {'os_codename': 'zesty', 'download_server': 'usa-nh',
#                          'pkgs': ['afni', 'dcm2niix']}),
#         ('spm', {'version': '12', 'matlab_version': 'R2017a'}),
#         ('instruction', 'RUN echo "Hello, World"'),
#         ('copy', ['rel/path/to/startup.sh', '/path/in/container/']),
#         ('user', 'neuro'),
#         ('env', {'KEY_A': 'VAL_A', 'KEY_B': 'VAL_B is "hello"'}),
#         ('env', {'KEY_C': 'based on $KEY_A'}),
#     ]
# }
#
# df = Dockerfile(specs)
# df.save('path/to/Dockerfile')
# print(df)
# ```

# %% [markdown]
# ## Using reprozip to capture some analysis
#
# A walkthrough is available here: http://nipy.org/workshops/2017-03-boston/lectures/repeatable-research/

# %%
# %%bash
#
# reprozip trace -d tracedir nib-ls /data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz
# Out:
# /data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz float32 [256, 156, 256] 1.00x1.30x1.00   sform
#
# Configuration file written in tracedir/config.yml
# Edit that file then run the packer -- use 'reprozip pack -h' for help
# Uploading usage statistics is currently disabled
# Please help us by providing anonymous usage statistics; you can enable this
# by running:
#     reprozip usage_report --enable
# If you do not want to see this message again, you can run:
#     reprozip usage_report --disable
# Nothing will be uploaded before you opt in.

# %% [markdown]
# ## View the trace

# %%
# %%bash
#
# cat tracedir/config.yml
# Out:
# # ReproZip configuration file
# # This file was generated by reprozip 1.0.9 at 2017-08-11T22:12:35.088333
#
# # You might want to edit this file before running the packer
# # See 'reprozip pack -h' for help
#
# # Run info
# version: "0.8"
# runs:
# # Run 0
# - architecture: x86_64
#   argv: [nib-ls, /data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz]
#   binary: /opt/conda/envs/neuro/bin/nib-ls
#   distribution: [debian, '9.1']
#   environ: {CLICOLOR: '1', CONDA_DIR: /opt/conda, GIT_PAGER: cat, HOME: /home/neuro,
#     HOSTNAME: 10eab4a5b4ea, JPY_PARENT_PID: '11', LANG: C.UTF-8, LC_ALL: C, LS_COLORS: 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.Z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:',
#     MPLBACKEND: 'module://ipykernel.pylab.backend_inline', ND_ENTRYPOINT: /neurodocker/startup.sh,
#     PAGER: cat, PATH: '/opt/conda/envs/neuro/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#     PWD: /home/neuro/test/notebooks, SHLVL: '3', TERM: xterm-color, _: /opt/conda/envs/neuro/bin/reprozip,
#     no_proxy: '*.local, 169.254/16'}
#   exitcode: 0
#   gid: 100
#   hostname: 10eab4a5b4ea
#   id: run0
#   system: [Linux, 4.9.38-moby]
#   uid: 1000
#   workingdir: /home/neuro/test/notebooks
#
# # Input and output files
#
# # Inputs are files that are only read by a run; reprounzip can replace these
# # files on demand to run the experiment with custom data.
# # Outputs are files that are generated by a run; reprounzip can extract these
# # files from the experiment on demand, for the user to examine.
# # The name field is the identifier the user will use to access these files.
# inputs_outputs:
# - name: cycler-0.10.0-py3.5.egg
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/cycler-0.10.0-py3.5.egg
#   written_by_runs: []
#   read_by_runs: [0]
# - name: spm2analyze.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/spm2analyze.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _collections_abc.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_collections_abc.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_48
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/jsmin-2.2.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: configparser.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/configparser.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: quaternions.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/quaternions.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: six.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/six.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_41
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/traitsui-5.1.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: reprlib.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/reprlib.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: quoprimime.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/quoprimime.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _methods.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/_methods.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: liblzma.so.5.2.2
#   path: /opt/conda/envs/neuro/lib/liblzma.so.5.2.2
#   written_by_runs: []
#   read_by_runs: [0]
# - name: result.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/result.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: version.cpython-35.pyc_4
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/__pycache__/version.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _import_tools.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/__pycache__/_import_tools.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _iotools.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/_iotools.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mtrand.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/random/mtrand.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ast.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/ast.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pyparsing.py
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/pyparsing.py
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _polybase.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/_polybase.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: function_base.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/function_base.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: nifti2.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/nifti2.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _socket.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_socket.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: utils.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/utils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_6
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/ma/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_17
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/wcwidth-0.1.7-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _compat_pickle.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_compat_pickle.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: namespace_packages.txt_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/keyrings.alt-2.2.dist-info/namespace_packages.txt
#   written_by_runs: []
#   read_by_runs: [0]
# - name: random.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/random.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: npyio.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/npyio.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: dis.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/dis.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: xmlutils.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/xmlutils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: linecache.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/linecache.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __about__.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/__about__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: matplotlib-2.0.2-py3.5-nspkg.pth
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/matplotlib-2.0.2-py3.5-nspkg.pth
#   written_by_runs: []
#   read_by_runs: [0]
# - name: nifti1.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/nifti1.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: sre_compile.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/sre_compile.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: util.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/gifti/__pycache__/util.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: fromnumeric.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/fromnumeric.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: optparse.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/optparse.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: py3k.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/py3k.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: encoders.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/encoders.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: namespace_packages.txt_3
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/matplotlib-2.0.2-py3.5.egg-info/namespace_packages.txt
#   written_by_runs: []
#   read_by_runs: [0]
# - name: locale.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/locale.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: polynomial.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/polynomial.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_14
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/compat/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ElementPath.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/ElementPath.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_36
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy-1.13.1-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_40
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/wheel-0.29.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _bootlocale.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_bootlocale.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_30
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/wrapt-1.10.11-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_24
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/Pygments-2.2.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: fftpack_lite.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/fft/fftpack_lite.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: subprocess.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/subprocess.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: select.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/select.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: threading.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/threading.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pkg_info.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/pkg_info.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: imageglobals.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/imageglobals.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pexpect-4.2.1-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pexpect-4.2.1-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_24
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ecat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/ecat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _compat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/_compat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: site.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/site.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: numbers.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/numbers.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mriutils.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/mriutils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: signal.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/signal.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_36
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/streamlines/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _weakrefset.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_weakrefset.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_32
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_18
#   path: /opt/conda/envs/neuro/lib/python3.5/xml/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _globals.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/__pycache__/_globals.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: minc2.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/minc2.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: socket.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/socket.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: types.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/types.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _ctypes.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_ctypes.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: math.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/math.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: lzma.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/lzma.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mghformat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/freesurfer/__pycache__/mghformat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mock.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/mock/__pycache__/mock.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: info.cpython-35.pyc_5
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/info.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_26
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/random/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: optpkg.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/optpkg.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: hashlib.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/hashlib.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: cycler.pth
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/cycler.pth
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_15
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy-0.19.1-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: parse_gifti_fast.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/gifti/__pycache__/parse_gifti_fast.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: funcs.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/funcs.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: signals.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/signals.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: namespace_packages.txt
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5.egg-info/namespace_packages.txt
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_58
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/seaborn-0.8-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: arrayterator.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/arrayterator.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: warnings.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/warnings.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: weakref.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/weakref.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: charset.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/charset.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_29
#   path: /opt/conda/envs/neuro/lib/python3.5/collections/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_7
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel-2.1.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: abc.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/importlib/__pycache__/abc.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_25
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/traits-4.6.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: core.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/ma/__pycache__/core.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: base64.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/base64.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_22
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: textwrap.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/textwrap.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: six.cpython-35.pyc_4
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/externals/__pycache__/six.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_12
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pyexpat.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/pyexpat.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: tractogram_file.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/streamlines/__pycache__/tractogram_file.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _version.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/_version.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: gettext.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/gettext.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: requirements.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/requirements.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pickle.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/pickle.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_3
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/chardet-3.0.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: sysconfig.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/sysconfig.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: einsumfunc.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/einsumfunc.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: parrec.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/parrec.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: fileslice.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/fileslice.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_37
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/cryptography-1.9-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _struct.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_struct.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: main.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/main.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_30
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/gifti/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _distributor_init.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/__pycache__/_distributor_init.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: loader.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/loader.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: argparse.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/argparse.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_46
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/simplejson-3.11.1-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: re.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/re.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: expat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/xml/parsers/__pycache__/expat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: libz.so.1.2.11
#   path: /opt/conda/envs/neuro/lib/libz.so.1.2.11
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_56
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/matplotlib-2.0.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: libopenblasp-r0.2.19.so
#   path: /opt/conda/envs/neuro/lib/libopenblasp-r0.2.19.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _hashlib.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_hashlib.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: feedparser.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/feedparser.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: copy.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/copy.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mixins.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/mixins.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: twodim_base.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/twodim_base.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: grp.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/grp.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: base64mime.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/base64mime.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_15
#   path: /opt/conda/envs/neuro/lib/python3.5/logging/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: message.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/message.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: fnmatch.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/fnmatch.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pyparsing.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/__pycache__/pyparsing.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: info.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/linalg/__pycache__/info.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: appdirs.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/__pycache__/appdirs.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_53
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/PyLD-0.7.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: polynomial.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/polynomial.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_18
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/prompt_toolkit-1.0.15-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _posixsubprocess.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_posixsubprocess.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_4
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/freesurfer/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_5
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/datalad-0.8.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: format.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/format.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: add_newdocs.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/__pycache__/add_newdocs.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_21
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/six-1.10.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: version.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/distutils/__pycache__/version.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: polyutils.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/polyutils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: shutil.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/shutil.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: contextlib.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/contextlib.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: tempfile.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/tempfile.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: abc.cpython-35.pyc_3
#   path: /opt/conda/envs/neuro/lib/python3.5/collections/__pycache__/abc.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: codecs.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/codecs.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_51
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/cffi-1.10.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/rpaths-0.12-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_23
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/mock/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_10
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/jedi-0.10.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: laguerre.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/laguerre.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ipython_genutils-0.2.0-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/ipython_genutils-0.2.0-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _datasource.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/_datasource.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: py31compat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/__pycache__/py31compat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: operator.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/operator.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_35
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/altair-1.2.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: quopri.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/quopri.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_39
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/asn1crypto-0.22.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _bz2.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_bz2.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: struct.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/struct.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _sitebuiltins.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_sitebuiltins.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: difflib.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/difflib.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_27
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/mistune-0.7.4-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: python
#   path: /opt/conda/envs/neuro/bin/python
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_14
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/reprozip-1.0.9-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _sysconfigdata.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/_sysconfigdata.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _version.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/_version.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_57
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/MarkupSafe-1.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _random.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_random.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: arrayproxy.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/arrayproxy.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: posixpath.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/posixpath.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: keyrings.alt-2.2-py3.6-nspkg.pth
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/keyrings.alt-2.2-py3.6-nspkg.pth
#   written_by_runs: []
#   read_by_runs: [0]
# - name: abc.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/abc.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ElementTree.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/ElementTree.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: specifiers.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/specifiers.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_9
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/msgpack_python-0.4.8-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: scimath.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/scimath.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: minc1.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/minc1.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: hermite.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/hermite.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: affines.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/affines.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: extras.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/ma/__pycache__/extras.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: gzip.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/gzip.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _heapq.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_heapq.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: utils.cpython-35.pyc_3
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/utils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: fileholders.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/fileholders.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: machinery.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/importlib/__pycache__/machinery.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_3
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pbr/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: enum.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/enum.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: openers.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/openers.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _internal.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/_internal.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: defmatrix.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/matrixlib/__pycache__/defmatrix.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: utils.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/testing/__pycache__/utils.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_38
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pyface-5.1.0-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: giftiio.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/gifti/__pycache__/giftiio.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: machar.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/machar.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: latin_1.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/encodings/__pycache__/latin_1.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: certifi-2017.07.27.1-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/certifi-2017.07.27.1-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _pickle.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_pickle.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: reprounzip-1.0.9-py3.5-nspkg.pth
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5-nspkg.pth
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_23
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/humanize-0.5.1-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: libpython3.5m.so.1.0
#   path: /opt/conda/envs/neuro/lib/libpython3.5m.so.1.0
#   written_by_runs: []
#   read_by_runs: [0]
# - name: traceback.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/traceback.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_19
#   path: /opt/conda/envs/neuro/lib/python3.5/ctypes/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: numeric.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/numeric.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PyYAML-3.12-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/PyYAML-3.12-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: qtconsole-4.3.0-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/qtconsole-4.3.0-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_10
#   path: /opt/conda/envs/neuro/lib/python3.5/importlib/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: python3.5
#   path: /opt/conda/envs/neuro/bin/python3.5
#   written_by_runs: []
#   read_by_runs: [0]
# - name: markers.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/__pycache__/markers.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: mmap.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/mmap.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: analyze.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/analyze.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: legendre.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/legendre.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _opcode.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/_opcode.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: platform.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/platform.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pydicom_compat.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/pydicom_compat.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: numerictypes.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/numerictypes.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: genericpath.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/genericpath.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: arrayprint.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/arrayprint.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: keyword.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/keyword.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: opcode.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/opcode.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_25
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: cp437.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/encodings/__pycache__/cp437.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: binascii.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/lib-dynload/binascii.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _umath_linalg.cpython-35m-x86_64-linux-gnu.so
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/linalg/_umath_linalg.cpython-35m-x86_64-linux-gnu.so
#   written_by_runs: []
#   read_by_runs: [0]
# - name: gifti.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/gifti/__pycache__/gifti.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: terminado-0.6-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/terminado-0.6-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: header.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/header.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: py3k.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/compat/__pycache__/py3k.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: index_tricks.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/index_tricks.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: tractogram.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/streamlines/__pycache__/tractogram.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_8
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/linalg/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: io.cpython-35.pyc_2
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/io.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: io.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/freesurfer/__pycache__/io.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_31
#   path: /opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: arraysetops.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/arraysetops.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: records.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/core/__pycache__/records.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: pathlib.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/pathlib.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: suite.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/suite.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: aliases.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/encodings/__pycache__/aliases.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_42
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/requests-2.18.3-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: ptyprocess-0.5.2-py3.5.egg-info
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/ptyprocess-0.5.2-py3.5.egg-info
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_17
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: libgfortran.so.3.0.0
#   path: /opt/conda/envs/neuro/lib/libgfortran.so.3.0.0
#   written_by_runs: []
#   read_by_runs: [0]
# - name: helper.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/fft/__pycache__/helper.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: version.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__pycache__/version.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: _parseaddr.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/email/__pycache__/_parseaddr.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: string.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/string.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: sre_constants.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/__pycache__/sre_constants.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: stride_tricks.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/lib/__pycache__/stride_tricks.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: batteryrunners.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/nibabel/__pycache__/batteryrunners.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: arg
#   path: /data/ds000114/.git/annex/objects/QP/jm/MD5E-s8677710--d6820f6cb8fb965e864419c14f6a22d5.nii.gz/MD5E-s8677710--d6820f6cb8fb965e864419c14f6a22d5.nii.gz
#   written_by_runs: []
#   read_by_runs: [0]
# - name: hermite_e.cpython-35.pyc
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/numpy/polynomial/__pycache__/hermite_e.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_33
#   path: /opt/conda/envs/neuro/lib/python3.5/encodings/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# - name: PKG-INFO_32
#   path: /opt/conda/envs/neuro/lib/python3.5/site-packages/pytz-2017.2-py3.5.egg-info/PKG-INFO
#   written_by_runs: []
#   read_by_runs: [0]
# - name: __init__.cpython-35.pyc_13
#   path: /opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/__init__.cpython-35.pyc
#   written_by_runs: []
#   read_by_runs: [0]
# ...
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/specifiers.py" # 27.37 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/packaging/version.py" # 11.29 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/pyparsing.py" # 224.48 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/_vendor/six.py" # 29.39 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/extern" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/extern/__init__.py" # 2.43 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/extern/__pycache__/__init__.cpython-35.pyc" # 2.45 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pkg_resources/py31compat.py" # 600.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/prompt_toolkit-1.0.15-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/prompt_toolkit-1.0.15-py3.5.egg-info/PKG-INFO" # 9.04 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/ptyprocess-0.5.2-py3.5.egg-info" # 264.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyOpenSSL-16.2.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyOpenSSL-16.2.0-py3.5.egg-info/PKG-INFO" # 3.66 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pycparser-2.18-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pycparser-2.18-py3.5.egg-info/PKG-INFO" # 602.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyface-5.1.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyface-5.1.0-py3.5.egg-info/PKG-INFO" # 3.08 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyparsing-2.2.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyparsing-2.2.0-py3.5.egg-info/PKG-INFO" # 920.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/python_dateutil-2.6.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/python_dateutil-2.6.1-py3.5.egg-info/PKG-INFO" # 1.09 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pythreejs-0.4.0a0.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pytz-2017.2-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pytz-2017.2-py3.5.egg-info/PKG-INFO" # 24.25 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyzmq-16.0.2-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/pyzmq-16.0.2-py3.5.egg-info/PKG-INFO" # 1.24 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/qtconsole-4.3.0-py3.5.egg-info" # 857.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5-nspkg.pth" # 1.79 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5.egg-info/PKG-INFO" # 2.49 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip-1.0.9-py3.5.egg-info/namespace_packages.txt" # 32.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprounzip/unpackers" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprozip-1.0.9-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/reprozip-1.0.9-py3.5.egg-info/PKG-INFO" # 2.57 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/requests-2.18.3-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/requests-2.18.3-py3.5.egg-info/PKG-INFO" # 61.37 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/rpaths-0.12-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/rpaths-0.12-py3.5.egg-info/PKG-INFO" # 979.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scikit_learn-0.19.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scikit_learn-0.19.0-py3.5.egg-info/PKG-INFO" # 8.05 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy-0.19.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy-0.19.1-py3.5.egg-info/PKG-INFO" # 2.10 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__config__.py" # 1.20 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__init__.py" # 4.78 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__pycache__/__config__.cpython-35.pyc" # 1.09 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__pycache__/__init__.cpython-35.pyc" # 4.40 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/__pycache__/version.cpython-35.pyc" # 257.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__init__.py" # 380.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/__init__.cpython-35.pyc" # 575.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/_ccallback.cpython-35.pyc" # 6.37 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/_version.cpython-35.pyc" # 4.97 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/__pycache__/six.cpython-35.pyc" # 6.51 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/_ccallback.py" # 6.05 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/_ccallback_c.cpython-35m-x86_64-linux-gnu.so" # 282.51 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/_version.py" # 4.68 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/_lib/six.py" # 7.24 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/scipy/version.py" # 198.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/seaborn-0.8-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/seaborn-0.8-py3.5.egg-info/PKG-INFO" # 1.93 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/setuptools-36.2.7.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/simplegeneric-0.8.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/simplegeneric-0.8.1-py3.5.egg-info/PKG-INFO" # 10.55 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/simplejson-3.11.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/simplejson-3.11.1-py3.5.egg-info/PKG-INFO" # 2.97 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/six-1.10.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/six-1.10.0-py3.5.egg-info/PKG-INFO" # 1.39 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/six.py" # 29.39 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/smmap2-2.0.3.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/statsmodels-0.8.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/statsmodels-0.8.0-py3.5.egg-info/PKG-INFO" # 6.81 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/terminado-0.6-py3.5.egg-info" # 3.80 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/testpath-0.3.1.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/tornado-4.5.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/tornado-4.5.1-py3.5.egg-info/PKG-INFO" # 2.79 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/tqdm-4.15.0.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traitlets-4.3.2.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traits-4.6.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traits-4.6.0-py3.5.egg-info/PKG-INFO" # 3.99 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traitsui-5.1.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traitsui-5.1.0-py3.5.egg-info/PKG-INFO" # 3.80 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/traittypes-0.0.6.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/urllib3-1.21.1-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/urllib3-1.21.1-py3.5.egg-info/PKG-INFO" # 37.54 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/usagestats-0.5-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/usagestats-0.5-py3.5.egg-info/PKG-INFO" # 4.18 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/vega-0.4.4-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/vega-0.4.4-py3.5.egg-info/PKG-INFO" # 1.40 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wcwidth-0.1.7-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wcwidth-0.1.7-py3.5.egg-info/PKG-INFO" # 10.03 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/webencodings-0.5.1.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wheel-0.29.0-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wheel-0.29.0-py3.5.egg-info/PKG-INFO" # 12.83 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/widgetsnbextension-3.0.0b11.dist-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wrapt-1.10.11-py3.5.egg-info" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/site-packages/wrapt-1.10.11-py3.5.egg-info/PKG-INFO" # 7.26 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/site.py" # 20.74 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/socket.py" # 26.50 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/sre_compile.py" # 17.98 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/sre_constants.py" # 6.66 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/sre_parse.py" # 34.29 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/stat.py" # 4.92 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/string.py" # 11.58 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/struct.py" # 257.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/subprocess.py" # 57.53 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/sysconfig.py" # 23.77 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/tempfile.py" # 26.01 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/textwrap.py" # 19.10 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/threading.py" # 47.88 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/token.py" # 3.00 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/tokenize.py" # 27.14 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/traceback.py" # 21.66 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/types.py" # 8.59 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__init__.py" # 3.07 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/__init__.cpython-35.pyc" # 3.02 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/case.cpython-35.pyc" # 49.51 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/loader.cpython-35.pyc" # 14.75 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/main.cpython-35.pyc" # 7.54 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/result.cpython-35.pyc" # 7.57 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/runner.cpython-35.pyc" # 7.30 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/signals.cpython-35.pyc" # 2.30 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/suite.cpython-35.pyc" # 9.66 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/__pycache__/util.cpython-35.pyc" # 5.08 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/case.py" # 55.59 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/loader.py" # 21.70 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/main.py" # 10.30 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/result.py" # 7.27 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/runner.py" # 7.57 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/signals.py" # 2.35 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/suite.py" # 10.23 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/unittest/util.py" # 5.31 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/urllib" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/urllib/__init__.py" # 0.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/urllib/__pycache__/__init__.cpython-35.pyc" # 115.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/urllib/__pycache__/parse.cpython-35.pyc" # 29.48 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/urllib/parse.py" # 33.78 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/uu.py" # 6.60 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/warnings.py" # 15.48 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/weakref.py" # 19.99 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/__init__.py" # 557.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/__pycache__/__init__.cpython-35.pyc" # 687.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/ElementPath.py" # 9.69 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/ElementTree.py" # 56.65 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/__init__.py" # 1.57 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/ElementPath.cpython-35.pyc" # 6.54 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/ElementTree.cpython-35.pyc" # 46.82 KB
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/etree/__pycache__/__init__.cpython-35.pyc" # 118.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/parsers" # Directory
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/parsers/__init__.py" # 167.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/parsers/__pycache__/__init__.cpython-35.pyc" # 294.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/parsers/__pycache__/expat.cpython-35.pyc" # 335.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/xml/parsers/expat.py" # 248.0 bytes
#   - "/opt/conda/envs/neuro/lib/python3.5/zipfile.py" # 71.95 KB
#   - "/usr/bin/dash" # 114.46 KB
#   - "/usr/bin/sh" # Link to /usr/bin/dash
#   - "/usr/bin/uname" # 34.76 KB
#   - "/usr/lib/x86_64-linux-gnu/ld-2.24.so" # 149.70 KB
#   - "/usr/lib/x86_64-linux-gnu/libc-2.24.so" # 1.61 MB
#   - "/usr/lib/x86_64-linux-gnu/libc.so.6" # Link to /usr/lib/x86_64-linux-gnu/libc-2.24.so
#   - "/usr/lib/x86_64-linux-gnu/libdl-2.24.so" # 14.30 KB
#   - "/usr/lib/x86_64-linux-gnu/libdl.so.2" # Link to /usr/lib/x86_64-linux-gnu/libdl-2.24.so
#   - "/usr/lib/x86_64-linux-gnu/libgcc_s.so.1" # 90.41 KB
#   - "/usr/lib/x86_64-linux-gnu/libm-2.24.so" # 1.01 MB
#   - "/usr/lib/x86_64-linux-gnu/libm.so.6" # Link to /usr/lib/x86_64-linux-gnu/libm-2.24.so
#   - "/usr/lib/x86_64-linux-gnu/libpthread-2.24.so" # 132.27 KB
#   - "/usr/lib/x86_64-linux-gnu/libpthread.so.0" # Link to /usr/lib/x86_64-linux-gnu/libpthread-2.24.so
#   - "/usr/lib/x86_64-linux-gnu/librt-2.24.so" # 31.00 KB
#   - "/usr/lib/x86_64-linux-gnu/librt.so.1" # Link to /usr/lib/x86_64-linux-gnu/librt-2.24.so
#   - "/usr/lib/x86_64-linux-gnu/libutil-2.24.so" # 10.44 KB
#   - "/usr/lib/x86_64-linux-gnu/libutil.so.1" # Link to /usr/lib/x86_64-linux-gnu/libutil-2.24.so
#   - "/usr/lib64/ld-linux-x86-64.so.2" # Link to /lib/x86_64-linux-gnu/ld-2.24.so
#
# # If you want to include additional files in the pack, you can list additional
# # patterns of files that will be included
# # Example:
# #additional_patterns:
# #  - /etc/apache2/**  # Everything under apache2/
# #  - /var/log/apache2/*.log  # Log files directly under apache2/
# #  - /var/lib/lxc/*/rootfs/home/**/*.py  # All Python files of all users in
# #    # that container

# %% [markdown]
# ## Pack the necessary files

# %%
# %%bash
#
# reprozip pack -d tracedir nibls.rpz
# Out:
# Uploading usage statistics is currently disabled
# Please help us by providing anonymous usage statistics; you can enable this
# by running:
#     reprozip usage_report --enable
# If you do not want to see this message again, you can run:
#     reprozip usage_report --disable
# Nothing will be uploaded before you opt in.

# %% [markdown]
# ## Unpack the trace on a different container

# %%
# %%bash
#
# reprounzip chroot setup --dont-bind-magic-dirs nibls.rpz nibbler
# Out:
# [REPROUNZIP] 22:14:21.013 WARNING: Not running as root, won't restore files' owner/group
#
# Uploading usage statistics is currently disabled
# Please help us by providing anonymous usage statistics; you can enable this
# by running:
#     reprounzip usage_report --enable
# If you do not want to see this message again, you can run:
#     reprounzip usage_report --disable
# Nothing will be uploaded before you opt in.

# %%
# %%bash
#
# tree -L 2 nibbler
# Out:
# nibbler
# |-- config.yml
# |-- inputs.tar.gz
# `-- root
#     |-- bin -> usr/bin
#     |-- data
#     |-- etc
#     |-- home
#     |-- lib -> usr/lib
#     |-- lib64 -> usr/lib64
#     |-- opt
#     `-- usr
#
# 9 directories, 2 files

# %% [markdown]
# ## Rerun the analysis

# %%
# %%bash
#
# reprounzip chroot run nibbler
# Out:
# chroot: cannot change root directory to 'nibbler/root': Operation not permitted
#
# *** Command finished, status: 125
#
# Uploading usage statistics is currently disabled
# Please help us by providing anonymous usage statistics; you can enable this
# by running:
#     reprounzip usage_report --enable
# If you do not want to see this message again, you can run:
#     reprounzip usage_report --disable
# Nothing will be uploaded before you opt in.

# %% [markdown]
# ## Minimize existing Docker image
#
# In the following example, a Docker image is built with ANTs version 2.2.0 and a functional scan. The image is minified for running `antsMotionCorr`. The original ANTs Docker image is 1.85 GB, and the "minified" image is 365 MB.
#
# ```shell
# # Create a Docker image with ANTs, and download a functional scan.
# download_cmd="RUN curl -sSL -o /home/func.nii.gz http://psydata.ovgu.de/studyforrest/phase2/sub-01/ses-movie/func/sub-01_ses-movie_task-movie_run-1_bold.nii.gz"
# neurodocker generate -b centos:7 -p yum --ants version=2.2.0 --instruction="$download_cmd" | docker build -t ants:2.2.0 -
#
# # Run the container.
# docker run --rm -it --name ants-reprozip-container --security-opt=seccomp:unconfined ants:2.2.0
#
# # (in a new terminal window)
# # Output a ReproZip pack file in ~/neurodocker-reprozip-output with the files
# # necessary to run antsMotionCorr.
# # See https://github.com/stnava/ANTs/blob/master/Scripts/antsMotionCorrExample
# cmd="antsMotionCorr -d 3 -a /home/func.nii.gz -o /home/func_avg.nii.gz"
# neurodocker reprozip ants-reprozip-container "$cmd"
#
# reprozip docker setup neurodocker-reprozip.rpz test
# ```
